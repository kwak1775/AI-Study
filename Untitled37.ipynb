# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
import pandas as pd
import numpy as np

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.pairplot(iris, hue='species')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
iris.boxplot()

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(), cbar=False, annot=True)

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 5A6D-7069
#
#  C:\Users\USER 디렉터리
#
# 2019-05-30  오후 07:25    <DIR>          .
# 2019-05-30  오후 07:25    <DIR>          ..
# 2019-04-15  오후 08:10    <DIR>          .anaconda
# 2019-05-15  오후 10:13    <DIR>          .atom
# 2019-04-29  오후 10:18    <DIR>          .conda
# 2019-04-29  오후 08:19                43 .condarc
# 2019-05-29  오후 10:34    <DIR>          .docker
# 2019-05-08  오후 09:21                52 .gitconfig
# 2019-05-30  오후 07:03    <DIR>          .ipynb_checkpoints
# 2019-04-05  오후 09:06    <DIR>          .ipython
# 2019-04-19  오후 09:05    <DIR>          .jupyter
# 2019-04-22  오후 09:24    <DIR>          .keras
# 2019-04-05  오후 09:06    <DIR>          .matplotlib
# 2019-04-05  오후 09:15                29 .python_history
# 2019-04-19  오후 08:15    <DIR>          .surprise_data
# 2019-05-15  오후 07:31             1,663 .viminfo
# 2019-05-29  오후 10:29    <DIR>          .VirtualBox
# 2019-03-30  오후 04:34    <DIR>          3D Objects
# 2019-05-23  오후 09:59               144 aaaaaa.npy
# 2019-05-07  오후 09:40            21,841 advanced_function.ipynb
# 2019-03-30  오후 04:34    <DIR>          Contacts
# 2019-05-27  오후 07:41    <DIR>          data
# 2019-05-28  오후 09:43            10,809 datetime.ipynb
# 2019-05-10  오후 08:23             4,412 Decorator function.ipynb
# 2019-05-10  오후 09:46            32,984 Decorator.ipynb
# 2019-05-29  오후 08:04    <DIR>          Desktop
# 2019-05-27  오후 07:33    <DIR>          Documents
# 2019-05-29  오후 08:03    <DIR>          Downloads
# 2019-05-08  오후 07:12    <DIR>          Favorites
# 2019-05-03  오후 09:10            18,646 Fibonacci.ipynb
# 2019-05-23  오후 07:06             2,684 InputOuput.ipynb
# 2019-04-29  오후 08:59             1,631 jhkwak_01.ipynb
# 2019-04-30  오후 08:29            15,836 kwak_0430_1.ipynb
# 2019-04-30  오후 08:47             4,755 kwak_0430_2.ipynb
# 2019-04-30  오후 10:08             8,114 kwak_0430_3.ipynb
# 2019-05-07  오후 10:22            85,193 kwak_epiphanies(저녁반).ipynb
# 2019-05-07  오후 10:15            29,813 LEGB.ipynb
# 2019-03-30  오후 04:34    <DIR>          Links
# 2019-05-03  오후 09:32             9,201 Markdown.ipynb
# 2019-05-08  오후 09:21                43 mercurial.ini
# 2019-05-23  오후 09:52                94 moon.pickle
# 2019-05-23  오후 09:28                52 moon.txt
# 2019-05-23  오후 09:41                34 moon2.txt
# 2019-03-30  오후 04:34    <DIR>          Music
# 2019-05-29  오후 07:14    <DIR>          OneDrive
# 2019-05-16  오후 08:25            19,178 OOP_3_Delegation__composition_and_inheritance.ipynb
# 2019-05-17  오후 07:48            21,741 OOP_4_Polymorphism.ipynb
# 2019-05-03  오후 07:50             2,163 선언문.ipynb
#               72개 파일           2,247,386 바이트
#               31개 디렉터리  167,950,680,064 바이트 남음

# %%
# !pip install graph
# Out:
# Collecting graph
#   Could not find a version that satisfies the requirement graph (from versions: )
# No matching distribution found for graph

# %%
# !pip install -q missingno   # option -u -q

# %%
iris.loc[1, 'petal_length'] = None

# %%
iris.dropna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 20            5.4          3.4           1.7          0.2     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 23            5.1          3.3           1.7          0.5     setosa
# 24            4.8          3.4           1.9          0.2     setosa
# 25            5.0          3.0           1.6          0.2     setosa
# 26            5.0          3.4           1.6          0.4     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# 30            4.8          3.1           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [149 rows x 5 columns]

# %%
iris[iris.petal_length.isnull()]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 1           4.9          3.0           NaN          0.2  setosa

# %%
import missingno as mino

# %%
dir(mino)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'bar',
#  'dendrogram',
#  'geoplot',
#  'heatmap',
#  'matrix',
#  'missingno',
#  'nullity_filter',
#  'nullity_sort',
#  'utils']

# %%
mino.matrix(iris)

# %%
mino.dendrogram(iris)

# %%
mino.bar(iris)
