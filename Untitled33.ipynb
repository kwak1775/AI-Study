# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
                  ,header = None)

# %%
data.rename({0:'sl',1:'sw',2:'pl',3:'pw',4:'class_'},axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sl        150 non-null float64
# sw        150 non-null float64
# pl        150 non-null float64
# pw        150 non-null float64
# class_    150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
data.describe()
# Out:
#                sl          sw          pl          pw
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data.boxplot()

# %%
# %matplotlib inline

# %%
pd.plot.scattermatrix
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-51d9a1bf90ce> in <module>
# ----> 1 pd.plot.scattermatrix
#
# AttributeError: module 'pandas' has no attribute 'plot'

# %%
import seaborn as sns

# %%
sns.pairplot(data,hue='class_')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data.corr()
# Out:
#           sl        sw        pl        pw
# sl  1.000000 -0.109369  0.871754  0.817954
# sw -0.109369  1.000000 -0.420516 -0.356544
# pl  0.871754 -0.420516  1.000000  0.962757
# pw  0.817954 -0.356544  0.962757  1.000000

# %%
data.cov()
# Out:
#           sl        sw        pl        pw
# sl  0.685694 -0.039268  1.273682  0.516904
# sw -0.039268  0.188004 -0.321713 -0.117981
# pl  1.273682 -0.321713  3.113179  1.296387
# pw  0.516904 -0.117981  1.296387  0.582414

# %%
data.skew()
# Out:
# sl    0.314911
# sw    0.334053
# pl   -0.274464
# pw   -0.104997
# dtype: float64

# %%
data.kurt()
# Out:
# sl   -0.552064
# sw    0.290781
# pl   -1.401921
# pw   -1.339754
# dtype: float64

# %%
data = pd.read_csv('data/tb.csv', engine='python')

# %%
data2 = data.melt(['iso2', 'year']).dropna()

# %%
data2.variable
# Out:
# 4            new_sp
# 5            new_sp
# 6            new_sp
# 7            new_sp
# 8            new_sp
# 9            new_sp
# 10           new_sp
# 11           new_sp
# 12           new_sp
# 13           new_sp
# 14           new_sp
# 15           new_sp
# 16           new_sp
# 17           new_sp
# 18           new_sp
# 35           new_sp
# 36           new_sp
# 37           new_sp
# 38           new_sp
# 39           new_sp
# 40           new_sp
# 41           new_sp
# 42           new_sp
# 43           new_sp
# 44           new_sp
# 57           new_sp
# 58           new_sp
# 59           new_sp
# 60           new_sp
# 61           new_sp
#             ...
# 120309    new_sp_fu
# 120387    new_sp_fu
# 120442    new_sp_fu
# 120444    new_sp_fu
# 120445    new_sp_fu
# 120471    new_sp_fu
# 120479    new_sp_fu
# 120504    new_sp_fu
# 120505    new_sp_fu
# 120506    new_sp_fu
# 120565    new_sp_fu
# 120589    new_sp_fu
# 120590    new_sp_fu
# 120591    new_sp_fu
# ...

# %%
data2.iso2.value_counts()
# Out:
# CA    449
# CK    370
# MN    239
# FJ    239
# SE    236
# DK    236
# SK    236
# CZ    236
# SI    236
# PL    236
# CH    236
# PT    235
# IT    235
# LT    235
# NL    235
# MK    234
# BA    234
# AM    234
# BE    234
# RO    234
# MD    232
# FI    232
# GE    232
# PY    229
# LV    229
# KE    228
# NO    226
# KR    226
# HN    226
# JO    226
#      ...
# DM    110
# TR    108
# BY    108
# YU    108
# TL    107
# TV    106
# NR    101
# BB    101
# AG     96
# MR     94
# VC     85
# TD     85
# RS     84
# ME     83
# NU     82
# GQ     78
# GD     77
# WF     68
# MZ     58
# KN     56
# SM     45
# AS     43
# TK     42
# MS     41
# TC     39
# BM     25
# VI     23
# AI     22
# MC     21
# VG     12
# Name: iso2, Length: 212, dtype: int64

# %%
data2.groupby(['variable']).mean()
# Out:
#                      year        value
# variable
# new_sp        2000.507336  9112.137268
# new_sp_f014   2001.680626   106.720389
# new_sp_f04    2006.847328     6.417303
# new_sp_f1524  2001.716807   761.138655
# new_sp_f2534  2001.712490   857.329841
# new_sp_f3544  2001.712668   587.705117
# new_sp_f4554  2001.726016   401.766234
# new_sp_f514   2006.849010    39.185644
# new_sp_f5564  2001.709664   277.324370
# new_sp_f65    2001.721243   256.435768
# new_sp_fu     2007.022140     2.549815
# new_sp_m014   2001.653570    79.711449
# new_sp_m04    2006.852041     8.806122
# new_sp_m1524  2001.697869   926.066026
# new_sp_m2534  2001.700919  1304.247285
# new_sp_m3544  2001.708455  1208.728446
# new_sp_m4554  2001.714167   987.455754
# new_sp_m514   2006.850374    28.975062
# new_sp_m5564  2001.706250   699.392083
# new_sp_m65    2001.700084   612.390142
# new_sp_mu     2007.025735     5.731618

# %%
tips = sns.load_dataset('tips')

# %%
tips.sex = tips.sex.map({'Female':0, 'Male':1})

# %%
tips.smoker = tips.smoker.map(lambda x: 0 if x=='No' else 1)

# %%
tips
# Out:
#      total_bill   tip  sex smoker   day    time  size
# 0         16.99  1.01    0      0   Sun  Dinner     2
# 1         10.34  1.66    1      0   Sun  Dinner     3
# 2         21.01  3.50    1      0   Sun  Dinner     3
# 3         23.68  3.31    1      0   Sun  Dinner     2
# 4         24.59  3.61    0      0   Sun  Dinner     4
# 5         25.29  4.71    1      0   Sun  Dinner     4
# 6          8.77  2.00    1      0   Sun  Dinner     2
# 7         26.88  3.12    1      0   Sun  Dinner     4
# 8         15.04  1.96    1      0   Sun  Dinner     2
# 9         14.78  3.23    1      0   Sun  Dinner     2
# 10        10.27  1.71    1      0   Sun  Dinner     2
# 11        35.26  5.00    0      0   Sun  Dinner     4
# 12        15.42  1.57    1      0   Sun  Dinner     2
# 13        18.43  3.00    1      0   Sun  Dinner     4
# 14        14.83  3.02    0      0   Sun  Dinner     2
# 15        21.58  3.92    1      0   Sun  Dinner     2
# ...
