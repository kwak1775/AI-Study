# %%
import matplotlib.pyplot as plt

# %%
plt.figure();

# %%
# plt.figure(facecolor='red')
plt.axes([0,0,1,1])
plt.axes([0.3,0.3,0.3,0.3])
plt.show()

# %%
plt.plot([1,2,3])

# %%
plt.title('Title', loc = 'left');
plt.xlabel('Xlabel')
plt.ylabel('Ylabel')
plt.xticks([1,2,3,4])
plt.yticks([1,2,3,4,5])
plt.grid()
plt.plot([3,4,5], color='red', marker='x', label='lggg')
plt.plot([2,4,5,6])
plt.legend(loc=4)

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('tableau-colorblind10')

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
plt.style.use('tableau-colorblind10')

# %%
tips.groupby('sex')['tip'].mean().plot.bar(label='a', figsize=(4,4))
plt.legend()
